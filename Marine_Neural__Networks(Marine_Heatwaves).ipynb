# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow import keras

# %%
raw_csv = pd.read_csv('Shifting_Seas_preprocessed.csv')
df = raw_csv.copy()
df.head()
# Out:
#    Year  Month  Tropical_group  Islands_group  Red_Sea  Latitude  Longitude  \
# 0  2015      1               0              0        1   20.0248    38.4931
# 1  2015      1               1              0        0  -18.2988   147.7782
# 2  2015      1               1              0        0   14.9768   -75.0233
# 3  2015      1               1              0        0  -18.3152   147.6486
# 4  2015      1               0              1        0   -0.8805   -90.9769
#
#    SST (°C)  pH Level  None  Low_to_Medium_Bleaching  High  Species Observed  \
# 0     29.47     8.107     1                        0     0               106
# 1     29.65     8.004     0                        0     1               116
# 2     28.86     7.947     0                        0     1                90
# 3     28.97     7.995     0                        1     0                94
# 4     28.60     7.977     1                        0     0               110
#
#    Marine Heatwave
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0

# %% [markdown]
# # Scaling the inputs

# %%
from sklearn.preprocessing import MinMaxScaler
#scaling only selected columns to boost model accuracy
columns_to_scale = ['SST (°C)', 'pH Level', 'Species Observed', 'Latitude', 'Longitude', 'Year', 'Month']
scaler = MinMaxScaler()

# %%
df[columns_to_scale] = scaler.fit_transform(df[columns_to_scale])
#updating the dataset with the scaled data

# %%
df
# Out:
#      Year  Month  Tropical_group  Islands_group  Red_Sea  Latitude  Longitude  \
# 0     0.0    0.0               0              0        1  0.997476   0.639809
# 1     0.0    0.0               1              0        0  0.002187   0.999839
# 2     0.0    0.0               1              0        0  0.866376   0.265840
# 3     0.0    0.0               1              0        0  0.001761   0.999412
# 4     0.0    0.0               0              1        0  0.454551   0.213282
# ..    ...    ...             ...            ...      ...       ...        ...
# 495   1.0    1.0               0              1        0  0.453585   0.213282
# 496   1.0    1.0               1              0        0  0.559810   0.754499
# 497   1.0    1.0               1              0        0  0.868095   0.265853
# 498   1.0    1.0               0              0        1  0.996813   0.639718
# 499   1.0    1.0               0              0        1  0.997889   0.639786
#
#      SST (°C)  pH Level  None  Low_to_Medium_Bleaching  High  \
# 0    0.609195  0.727554     1                        0     0
# 1    0.628004  0.408669     0                        0     1
# 2    0.545455  0.232198     0                        0     1
# 3    0.556949  0.380805     0                        1     0
# 4    0.518286  0.325077     1                        0     0
# ..        ...       ...   ...                      ...   ...
# 495  0.735632  0.207430     0                        1     0
# 496  0.820272  0.247678     0                        1     0
# 497  0.500522  0.560372     0                        1     0
# 498  0.430512  0.820433     0                        1     0
# 499  0.463950  0.699690     1                        0     0
#
#      Species Observed  Marine Heatwave
# 0            0.444444                0
# 1            0.529915                0
# 2            0.307692                0
# 3            0.341880                0
# 4            0.478632                0
# ..                ...              ...
# 495          0.461538                1
# 496          0.230769                1
# 497          0.316239                0
# 498          0.461538                0
# 499          0.641026                0
#
# [500 rows x 14 columns]

# %% [markdown]
# # Balancing the dataset

# %%
df['Marine Heatwave'].value_counts()
# Out:
# Marine Heatwave
# 0    427
# 1     73
# Name: count, dtype: int64

# %%
#splitting the data into inputs and targets variables
scaled_inputs = df.drop(['Marine Heatwave'], axis=1)
target = df['Marine Heatwave']

# %%
from imblearn.over_sampling import SMOTE
from collections import Counter

# Initialize SMOTE
smote = SMOTE(random_state=42)

# Resample inputs and targets
X_resampled, y_resampled = smote.fit_resample(scaled_inputs, target)

# %%
inputs = X_resampled
targets = y_resampled

# %% [markdown]
# # Shuffling the dataset

# %%
shuffled_indices = np.arange(inputs.shape[0])
np.random.shuffle(shuffled_indices)

shuffled_inputs = inputs.iloc[shuffled_indices]
shuffled_targets = targets.iloc[shuffled_indices]

# %% [markdown]
# # Train, Test and Validation

# %%
# Get total number of samples after shuffling
Samples_count = shuffled_inputs.shape[0]

# Calculate how many samples will go into training set (80% of total), validation set (10% of total) and test set (10% of total)
train_samples_count = int(0.8 * Samples_count)
validation_samples_count = int(0.1 * Samples_count)
test_samples_count = Samples_count - train_samples_count - validation_samples_count

# Slice the shuffled data to get the training inputs and shuffled targets to get the training targets.
train_inputs = shuffled_inputs[:train_samples_count]
train_targets = shuffled_targets[:train_samples_count]

# Slice the next part of shuffled data for validation inputs and the corresponding targets for validation
validation_inputs = shuffled_inputs[train_samples_count:train_samples_count+validation_samples_count]
validation_targets = shuffled_targets[train_samples_count:train_samples_count+validation_samples_count]

# The remaining samples are used for test inputs and corresponding targets for the test inputs
test_inputs = shuffled_inputs[train_samples_count+validation_samples_count:]
test_targets = shuffled_targets[train_samples_count+validation_samples_count:]

# Print the number of positive samples (sum of targets), total samples, and the proportion for training set, validation set and test set
print(np.sum(train_targets), train_samples_count, np.sum(train_targets) / train_samples_count)
print(np.sum(validation_targets), validation_samples_count, np.sum(validation_targets) / validation_samples_count)
print(np.sum(test_targets), test_samples_count, np.sum(test_targets) / test_samples_count)
# Out:
# 350 683 0.5124450951683748
# 43 85 0.5058823529411764
# 34 86 0.3953488372093023

# %%
 np.savez('Shifting_Seas_data_train', inputs=train_inputs, targets=train_targets)
 np.savez('Shifting_Seas_data_validation', inputs=validation_inputs, targets=validation_targets)
 np.savez('Shifting_Seas_data_test', inputs=test_inputs, targets=test_targets)

# %% [markdown]
# # Building the NN model

# %%
# Load train data
npz = np.load('Shifting_Seas_data_train.npz')
train_inputs = npz['inputs'].astype(float)       # OR use np.float64
train_targets = npz['targets'].astype(int)        # OR use np.int64

# Load validation data
npz = np.load('Shifting_Seas_data_validation.npz')
validation_inputs = npz['inputs'].astype(float)
validation_targets = npz['targets'].astype(int)

# Load test data
npz = np.load('Shifting_Seas_data_test.npz')
test_inputs = npz['inputs'].astype(float)
test_targets = npz['targets'].astype(int)

# %%
input_size = 13
output_size = 2
hidden_layer_size = 50
model = tf.keras.Sequential([
    tf.keras.layers.Dense(hidden_layer_size, activation='relu'),
    tf.keras.layers.Dense(hidden_layer_size, activation='relu'),
    tf.keras.layers.Dense(output_size, activation='softmax')
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
batch_size = 100
max_epochs = 100
early_stopping = tf.keras.callbacks.EarlyStopping(patience=2)
model.fit(train_inputs, train_targets, batch_size=batch_size, epochs=max_epochs,callbacks=[early_stopping], validation_data=(validation_inputs, validation_targets), verbose=2)
# Out:
# Epoch 1/100
# 7/7 - 2s - 217ms/step - accuracy: 0.5315 - loss: 0.6890 - val_accuracy: 0.6588 - val_loss: 0.6409
# Epoch 2/100
# 7/7 - 0s - 20ms/step - accuracy: 0.6413 - loss: 0.6471 - val_accuracy: 0.7294 - val_loss: 0.6104
# Epoch 3/100
# 7/7 - 0s - 20ms/step - accuracy: 0.7350 - loss: 0.6227 - val_accuracy: 0.7647 - val_loss: 0.5844
# Epoch 4/100
# 7/7 - 0s - 14ms/step - accuracy: 0.7643 - loss: 0.5951 - val_accuracy: 0.8000 - val_loss: 0.5551
# Epoch 5/100
# 7/7 - 0s - 20ms/step - accuracy: 0.7818 - loss: 0.5665 - val_accuracy: 0.7882 - val_loss: 0.5264
# Epoch 6/100
# 7/7 - 0s - 15ms/step - accuracy: 0.7994 - loss: 0.5382 - val_accuracy: 0.8235 - val_loss: 0.4941
# Epoch 7/100
# 7/7 - 0s - 13ms/step - accuracy: 0.8272 - loss: 0.5061 - val_accuracy: 0.8706 - val_loss: 0.4602
# Epoch 8/100
# 7/7 - 0s - 20ms/step - accuracy: 0.8419 - loss: 0.4718 - val_accuracy: 0.8706 - val_loss: 0.4255
# Epoch 9/100
# 7/7 - 0s - 20ms/step - accuracy: 0.8668 - loss: 0.4352 - val_accuracy: 0.8941 - val_loss: 0.3879
# Epoch 10/100
# 7/7 - 0s - 20ms/step - accuracy: 0.8799 - loss: 0.3970 - val_accuracy: 0.9412 - val_loss: 0.3512
# Epoch 11/100
# 7/7 - 0s - 13ms/step - accuracy: 0.8946 - loss: 0.3598 - val_accuracy: 0.9529 - val_loss: 0.3149
# Epoch 12/100
# 7/7 - 0s - 13ms/step - accuracy: 0.9122 - loss: 0.3247 - val_accuracy: 0.9529 - val_loss: 0.2835
# Epoch 13/100
# 7/7 - 0s - 20ms/step - accuracy: 0.9253 - loss: 0.2940 - val_accuracy: 0.9529 - val_loss: 0.2607
# Epoch 14/100
# 7/7 - 0s - 19ms/step - accuracy: 0.9239 - loss: 0.2679 - val_accuracy: 0.9529 - val_loss: 0.2379
# Epoch 15/100
# 7/7 - 0s - 14ms/step - accuracy: 0.9385 - loss: 0.2455 - val_accuracy: 0.9529 - val_loss: 0.2186
# Epoch 16/100
# 7/7 - 0s - 13ms/step - accuracy: 0.9429 - loss: 0.2273 - val_accuracy: 0.9529 - val_loss: 0.2085
# Epoch 17/100
# 7/7 - 0s - 20ms/step - accuracy: 0.9458 - loss: 0.2123 - val_accuracy: 0.9529 - val_loss: 0.1953
# Epoch 18/100
# 7/7 - 0s - 19ms/step - accuracy: 0.9473 - loss: 0.1980 - val_accuracy: 0.9529 - val_loss: 0.1867
# Epoch 19/100
# 7/7 - 0s - 13ms/step - accuracy: 0.9517 - loss: 0.1871 - val_accuracy: 0.9529 - val_loss: 0.1766
# Epoch 20/100
# 7/7 - 0s - 20ms/step - accuracy: 0.9429 - loss: 0.1782 - val_accuracy: 0.9529 - val_loss: 0.1714
# Epoch 21/100
# 7/7 - 0s - 20ms/step - accuracy: 0.9561 - loss: 0.1696 - val_accuracy: 0.9412 - val_loss: 0.1688
# Epoch 22/100
# 7/7 - 0s - 21ms/step - accuracy: 0.9370 - loss: 0.1699 - val_accuracy: 0.9412 - val_loss: 0.1672
# Epoch 23/100
# 7/7 - 0s - 28ms/step - accuracy: 0.9531 - loss: 0.1601 - val_accuracy: 0.9412 - val_loss: 0.1604
# Epoch 24/100
# 7/7 - 0s - 25ms/step - accuracy: 0.9502 - loss: 0.1543 - val_accuracy: 0.9647 - val_loss: 0.1459
# Epoch 25/100
# 7/7 - 0s - 43ms/step - accuracy: 0.9575 - loss: 0.1495 - val_accuracy: 0.9529 - val_loss: 0.1525
# Epoch 26/100
# 7/7 - 0s - 24ms/step - accuracy: 0.9473 - loss: 0.1449 - val_accuracy: 0.9647 - val_loss: 0.1379
# Epoch 27/100
# 7/7 - 0s - 44ms/step - accuracy: 0.9546 - loss: 0.1382 - val_accuracy: 0.9294 - val_loss: 0.1550
# Epoch 28/100
# 7/7 - 0s - 42ms/step - accuracy: 0.9590 - loss: 0.1358 - val_accuracy: 0.9647 - val_loss: 0.1319
# Epoch 29/100
# 7/7 - 0s - 25ms/step - accuracy: 0.9590 - loss: 0.1356 - val_accuracy: 0.9529 - val_loss: 0.1419
# Epoch 30/100
# 7/7 - 0s - 24ms/step - accuracy: 0.9531 - loss: 0.1319 - val_accuracy: 0.9647 - val_loss: 0.1300
# Epoch 31/100
# 7/7 - 0s - 45ms/step - accuracy: 0.9619 - loss: 0.1280 - val_accuracy: 0.9647 - val_loss: 0.1276
# Epoch 32/100
# 7/7 - 0s - 14ms/step - accuracy: 0.9561 - loss: 0.1248 - val_accuracy: 0.9647 - val_loss: 0.1201
# Epoch 33/100
# 7/7 - 0s - 20ms/step - accuracy: 0.9619 - loss: 0.1203 - val_accuracy: 0.9529 - val_loss: 0.1349
# Epoch 34/100
# 7/7 - 0s - 14ms/step - accuracy: 0.9605 - loss: 0.1227 - val_accuracy: 0.9647 - val_loss: 0.1165
# Epoch 35/100
# 7/7 - 0s - 14ms/step - accuracy: 0.9619 - loss: 0.1169 - val_accuracy: 0.9529 - val_loss: 0.1247
# Epoch 36/100
# 7/7 - 0s - 14ms/step - accuracy: 0.9678 - loss: 0.1135 - val_accuracy: 0.9647 - val_loss: 0.1146
# Epoch 37/100
# 7/7 - 0s - 20ms/step - accuracy: 0.9605 - loss: 0.1112 - val_accuracy: 0.9529 - val_loss: 0.1166
# Epoch 38/100
# 7/7 - 0s - 19ms/step - accuracy: 0.9634 - loss: 0.1089 - val_accuracy: 0.9647 - val_loss: 0.1098
# Epoch 39/100
# 7/7 - 0s - 22ms/step - accuracy: 0.9634 - loss: 0.1076 - val_accuracy: 0.9529 - val_loss: 0.1109
# Epoch 40/100
# 7/7 - 0s - 13ms/step - accuracy: 0.9649 - loss: 0.1039 - val_accuracy: 0.9529 - val_loss: 0.1089
# Epoch 41/100
# 7/7 - 0s - 19ms/step - accuracy: 0.9663 - loss: 0.1023 - val_accuracy: 0.9529 - val_loss: 0.1111
# Epoch 42/100
# 7/7 - 0s - 21ms/step - accuracy: 0.9678 - loss: 0.1035 - val_accuracy: 0.9647 - val_loss: 0.1002
# Epoch 43/100
# 7/7 - 0s - 19ms/step - accuracy: 0.9663 - loss: 0.0995 - val_accuracy: 0.9529 - val_loss: 0.1123
# Epoch 44/100
# 7/7 - 0s - 13ms/step - accuracy: 0.9736 - loss: 0.0945 - val_accuracy: 0.9647 - val_loss: 0.0964
# Epoch 45/100
# 7/7 - 0s - 20ms/step - accuracy: 0.9634 - loss: 0.0960 - val_accuracy: 0.9529 - val_loss: 0.1015
# Epoch 46/100
# 7/7 - 0s - 20ms/step - accuracy: 0.9707 - loss: 0.0934 - val_accuracy: 0.9529 - val_loss: 0.1031

# %% [markdown]
# # Testing the Model

# %%
test_loss, test_accuracy = model.evaluate(test_inputs, test_targets)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9572 - loss: 0.1543

# %%
print('\nTest loss: {0:.2f}. Test accuracy: {1:.2f}%'.format(test_loss, test_accuracy*100.))
# Out:
# Test loss: 0.19. Test accuracy: 95.35%
